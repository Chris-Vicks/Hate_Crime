# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
directory = '../data/Hate_crime1'

# %%
csv_files = [file for file in os.listdir(directory) if file.endswith('.csv')]

# %%
dataframes = []

# %%
for file in csv_files:
    file_path = os.path.join(directory, file)
    df = pd.read_csv(file_path)
    dataframes.append(df)
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_22304\2607106099.py:3: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df
# Out:
#         Unnamed: 0  INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME  \
# 0          11256.0        15761       1993  AK0010100       Anchorage
# 1          11257.0        15762       1993  AK0010100       Anchorage
# 2          11258.0        15763       1993  AK0010100       Anchorage
# 3          11259.0        15764       1993  AK0010100       Anchorage
# 4          11260.0        15765       1993  AK0010100       Anchorage
# ...            ...          ...        ...        ...             ...
# 426963    219068.0      1318026       2020  WY0170100        Sheridan
# 426964    219069.0      1142103       2020  WY0210100        Evanston
# 426965    219070.0      1318018       2020  WY0210100        Evanston
# 426966    219071.0      1318022       2020  WY0210100        Evanston
# 426967    219072.0      1318023       2020  WY0210100        Evanston
#
#        PUB_AGENCY_UNIT AGENCY_TYPE_NAME STATE_ABBR STATE_NAME DIVISION_NAME  \
# 0                  NaN             City         AK     Alaska       Pacific
# 1                  NaN             City         AK     Alaska       Pacific
# 2                  NaN             City         AK     Alaska       Pacific
# 3                  NaN             City         AK     Alaska       Pacific
# 4                  NaN             City         AK     Alaska       Pacific
# ...                ...              ...        ...        ...           ...
# 426963             NaN             City         WY    Wyoming      Mountain
# 426964             NaN             City         WY    Wyoming      Mountain
# 426965             NaN             City         WY    Wyoming      Mountain
# 426966             NaN             City         WY    Wyoming      Mountain
# 426967             NaN             City         WY    Wyoming      Mountain
#
#         ...              OFFENDER_RACE      OFFENDER_ETHNICITY VICTIM_COUNT  \
# 0       ...                      White                     NaN            2
# 1       ...                      White                     NaN            2
# 2       ...                    Unknown                     NaN            1
# 3       ...  Black or African American                     NaN            1
# 4       ...                      White                     NaN            1
# ...     ...                        ...                     ...          ...
# 426963  ...                      White  Not Hispanic or Latino            2
# 426964  ...                    Unknown                 Unknown            1
# 426965  ...  Black or African American  Not Hispanic or Latino            1
# 426966  ...                      White  Not Hispanic or Latino            1
# 426967  ...                      White  Not Hispanic or Latino            1
#
#                                     OFFENSE_NAME  TOTAL_INDIVIDUAL_VICTIMS  \
# 0                             Aggravated Assault                       2.0
# 1                             Aggravated Assault                       2.0
# 2                                   Intimidation                       1.0
# 3                                 Simple Assault                       1.0
# 4                                   Intimidation                       1.0
# ...                                          ...                       ...
# 426963                              Intimidation                       2.0
# 426964  Destruction/Damage/Vandalism of Property                       0.0
# 426965                        Aggravated Assault                       1.0
# 426966                            Simple Assault                       1.0
# 426967                       Theft From Building                       1.0
#
#                              LOCATION_NAME  \
# 0                  Parking/Drop Lot/Garage
# 1                            Bar/Nightclub
# 2               Government/Public Building
# 3       Highway/Road/Alley/Street/Sidewalk
# 4                           Residence/Home
# ...                                    ...
# 426963                     Park/Playground
# 426964                     Park/Playground
# 426965                      Residence/Home
# 426966                      Residence/Home
# 426967                      Residence/Home
#
#                                                 BIAS_DESC  VICTIM_TYPES  \
# 0                                         Anti-Gay (Male)    Individual
# 1                          Anti-Black or African American    Individual
# 2                          Anti-Black or African American    Individual
# 3                                              Anti-White    Individual
# 4                                              Anti-Asian    Individual
# ...                                                   ...           ...
# 426963  Anti-Lesbian, Gay, Bisexual, or Transgender (M...    Individual
# 426964                                         Anti-White    Government
# 426965                                         Anti-White    Individual
# 426966                                        Anti-Female    Individual
# 426967                         Anti-Gender Non-Conforming    Individual
#
#         MULTIPLE_OFFENSE MULTIPLE_BIAS
# 0                      S             S
# 1                      S             S
# 2                      S             S
# 3                      S             S
# 4                      S             S
# ...                  ...           ...
# 426963                 S             S
# 426964                 S             S
# 426965                 S             S
# 426966                 S             S
# 426967                 S             S
#
# [426968 rows x 29 columns]

# %%
# Save the combined DataFrame to a different directory
#combined_df.to_csv('../src/combined_data.csv', index=False)

# %%
correlation_matrix = combined_df.corr()
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_22304\1392662277.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = combined_df.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap')
plt.show()
